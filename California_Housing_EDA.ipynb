# %% [markdown]
# <a href="https://colab.research.google.com/github/papagorgio23/Python101/blob/master/California_Housing_EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Import Pandas Library
import pandas as pd
import numpy as np

# %%
# Import Data
df = pd.read_csv('/content/sample_data/california_housing_train.csv')

df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -114.31     34.19                15.0       5612.0          1283.0
# 1    -114.47     34.40                19.0       7650.0          1901.0
# 2    -114.56     33.69                17.0        720.0           174.0
# 3    -114.57     33.64                14.0       1501.0           337.0
# 4    -114.57     33.57                20.0       1454.0           326.0
#
#    population  households  median_income  median_house_value
# 0      1015.0       472.0         1.4936             66900.0
# 1      1129.0       463.0         1.8200             80100.0
# 2       333.0       117.0         1.6509             85700.0
# 3       515.0       226.0         3.1917             73400.0
# 4       624.0       262.0         1.9250             65500.0

# %%
df.dtypes
# Out:
# longitude             float64
# latitude              float64
# housing_median_age    float64
# total_rooms           float64
# total_bedrooms        float64
# population            float64
# households            float64
# median_income         float64
# median_house_value    float64
# dtype: object

# %%
df.describe()
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  17000.000000  17000.000000        17000.000000  17000.000000
# mean    -119.562108     35.625225           28.589353   2643.664412
# std        2.005166      2.137340           12.586937   2179.947071
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.790000     33.930000           18.000000   1462.000000
# 50%     -118.490000     34.250000           29.000000   2127.000000
# 75%     -118.000000     37.720000           37.000000   3151.250000
# max     -114.310000     41.950000           52.000000  37937.000000
#
#        total_bedrooms    population    households  median_income  \
# count    17000.000000  17000.000000  17000.000000   17000.000000
# mean       539.410824   1429.573941    501.221941       3.883578
# std        421.499452   1147.852959    384.520841       1.908157
# min          1.000000      3.000000      1.000000       0.499900
# ...

# %%
import matplotlib.pyplot as plt

# Plot Historgram
plt.hist(df['median_house_value']) 
plt.show()

# %%
num_bins = 7

# Plot Historgram
plt.hist(df['median_house_value'],num_bins,facecolor = 'k', edgecolor = 'black', alpha = 0.6) 
plt.xlabel ('Median Home Price')
plt.ylabel ( 'Count of Homes')
plt.title('Distribution of Median Home Values')
plt.show()

# %%
import seaborn as sns
sns.scatterplot(x=df['housing_median_age'], y = df['median_house_value'])
plt.show()

# %%
sns.scatterplot(x=df['households'], y = df['median_house_value'])
# sns.lineplot(x=df['median_house_value'], y= df[''])

# %%
g, axes = plt.subplots(2, 2, figsize=(10, 10), sharex=False, sharey=False)
sns.scatterplot(x=df['total_bedrooms'], y = df['median_house_value'], ax=axes[0, 0])
sns.scatterplot(x=df['total_rooms'], y = df['median_house_value'], ax = axes[0,1])
sns.scatterplot(x=df['median_income'], y = df['median_house_value'],ax = axes[1,0])
sns.scatterplot(x=df['population'], y = df['median_house_value'], ax = axes[1,1])


plt.show()

# %%
# df.dtypes
import seaborn as sns
plt.style.use('fivethirtyeight')
sns.jointplot(x= 'median_income', y = 'median_house_value', data = df, color = 'green',kind = 'reg')
plt.show()

# %%
def bin_function(pAge):
  if (pAge < 18.0):
    result = "young"
  elif (pAge<32.0):
    result = "avg"
  else:
    result = "old"
  return result

df['age_bins'] = df['housing_median_age'].apply(bin_function)
df
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -114.31     34.19                15.0       5612.0          1283.0
# 1        -114.47     34.40                19.0       7650.0          1901.0
# 2        -114.56     33.69                17.0        720.0           174.0
# 3        -114.57     33.64                14.0       1501.0           337.0
# 4        -114.57     33.57                20.0       1454.0           326.0
# 5        -114.58     33.63                29.0       1387.0           236.0
# 6        -114.58     33.61                25.0       2907.0           680.0
# 7        -114.59     34.83                41.0        812.0           168.0
# 8        -114.59     33.61                34.0       4789.0          1175.0
# 9        -114.60     34.83                46.0       1497.0           309.0
# 10       -114.60     33.62                16.0       3741.0           801.0
# ...

# %%
df['housing_median_age'].dtype
# Out:
# dtype('float64')

# %%
df['age_bins'] = df['housing_median_age']

# %%
df['housing_median_age'] < 18
# Out:
# 0         True
# 1        False
# 2         True
# 3         True
# 4        False
# 5        False
# 6        False
# 7        False
# 8        False
# 9        False
# 10        True
# 11       False
# 12       False
# 13       False
# 14        True
# 15        True
# 16       False
# 17       False
# 18        True
# 19        True
# 20       False
# 21       False
# 22       False
# 23        True
# 24       False
# 25       False
# 26       False
# 27        True
# 28       False
# 29       False
#          ...
# 16970    False
# 16971    False
# 16972    False
# 16973    False
# 16974    False
# 16975    False
# 16976     True
# 16977    False
# 16978    False
# 16979    False
# 16980    False
# 16981    False
# 16982    False
# 16983     True
# 16984    False
# 16985    False
# 16986    False
# 16987     True
# 16988    False
# 16989    False
# 16990    False
# 16991     True
# 16992    False
# 16993    False
# 16994    False
# 16995    False
# 16996    False
# ...
